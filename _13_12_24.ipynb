# %%
import pandas as pd

# %%
df = pd.read_csv("placement - placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head(5)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail(5)
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()   # static view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()    # Data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df = df.iloc[:4,:3]    # iloce [row_range, column_range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3, ['cgpa','placed']]    # loc[row_range, column_range]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
df.shape
# Out:
# (100, 3)

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p = df.dtypes      # it defines the data type of each column
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b =df.empty       # it returns TRUE if there is any missing value in data otherwise false
b
# Out:
# False

# %%
df.isnull().sum()   #for chechking missing values
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna()   # for remove missing row

# %%
i = df.ndim    # numbber of axes
i
# Out:
# 2

# %%
t = df.shape    # shape = n(rows),n(columns)
t
# Out:
# (100, 3)

# %%
d = df.size     # row count * column count
d
# Out:
# 300

# %%
a = df.values    
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()   # use to copy data

# %%
p = df.sort_values(by = 'resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
df['Cgpa'] = df['cgpa'].astype(int)

# %%
df
# Out:
#     cgpa  resume_score  placed  Cgpa
# 0      8          6.52       1     8
# 1      6          5.17       0     6
# 2      8          8.86       1     8
# 3      6          7.27       1     6
# 4      7          7.30       1     7
# ..   ...           ...     ...   ...
# 95     6          6.38       0     6
# 96     8          7.76       1     8
# 97     6          7.78       0     6
# 98     8          5.63       1     8
# 99     6          6.61       0     6
#
# [100 rows x 4 columns]

# %%
df = df.drop(columns = ['Cgpa'])

# %%
p = df

# %%
p['cgpa'] = p['cgpa'].astype(int)
p
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
p['resume_score']= p['resume_score'].astype(int)
p
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
t = df.add(4)     # to add in each column 
t
# Out:
#     cgpa  resume_score  placed
# 0     12            10       5
# 1     10             9       4
# 2     12            12       5
# 3     10            11       5
# 4     11            11       5
# ..   ...           ...     ...
# 95    10            10       4
# 96    12            11       5
# 97    10            11       4
# 98    12             9       5
# 99    10            10       4
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].add(4)    # to add in specific column
df
# Out:
#     cgpa  resume_score  placed
# 0     20             6       1
# 1     18             5       0
# 2     20             8       1
# 3     18             7       1
# 4     19             7       1
# ..   ...           ...     ...
# 95    18             6       0
# 96    20             7       1
# 97    18             7       0
# 98    20             5       1
# 99    18             6       0
#
# [100 rows x 3 columns]

# %%
df['resume_score'] = df['resume_score'].add(4)    # to add in specific column
df
# Out:
#     cgpa  resume_score  placed
# 0     20            10       1
# 1     18             9       0
# 2     20            12       1
# 3     18            11       1
# 4     19            11       1
# ..   ...           ...     ...
# 95    18            10       0
# 96    20            11       1
# 97    18            11       0
# 98    20             9       1
# 99    18            10       0
#
# [100 rows x 3 columns]

# %%
df['placed'] = df['placed'].add(4)    # to add in specific column
df
# Out:
#     cgpa  resume_score  placed
# 0     20            10       5
# 1     18             9       4
# 2     20            12       5
# 3     18            11       5
# 4     19            11       5
# ..   ...           ...     ...
# 95    18            10       4
# 96    20            11       5
# 97    18            11       4
# 98    20             9       5
# 99    18            10       4
#
# [100 rows x 3 columns]

# %%
s = df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p = df.max()
p
# Out:
# cgpa            21
# resume_score    13
# placed           5
# dtype: int64

# %%
q = df.min()
q
# Out:
# cgpa            17
# resume_score     8
# placed           4
# dtype: int64

# %%
r = df['cgpa'].mean()
r
# Out:
# 18.47

# %%
s = df['cgpa'].median()
s
# Out:
# 18.0

# %%
g = df.filter(items = ['cgpa', 'placed'])
g
# Out:
#     cgpa  placed
# 0     20       5
# 1     18       4
# 2     20       5
# 3     18       5
# 4     19       5
# ..   ...     ...
# 95    18       4
# 96    20       5
# 97    18       4
# 98    20       5
# 99    18       4
#
# [100 rows x 2 columns]

# %%
df[['cgpa', 'placed']]     # second option of filtering
# Out:
#     cgpa  placed
# 0     20       5
# 1     18       4
# 2     20       5
# 3     18       5
# 4     19       5
# ..   ...     ...
# 95    18       4
# 96    20       5
# 97    18       4
# 98    20       5
# 99    18       4
#
# [100 rows x 2 columns]

# %%
s =df.filter(items = [5,6], axis = 0)    ## axis = 0 it means row wise operation
s
# Out:
#    cgpa  resume_score  placed
# 5    20            10       5
# 6    17            11       4

# %%
p = df.rename(columns = {'cgpa': 'updated_cgpa',        # how to rename a column
                        'resume_score': 'semester_marks'})
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             20              10       5
# 1             18               9       4
# 2             20              12       5
# 3             18              11       5
# 4             19              11       5
# ..           ...             ...     ...
# 95            18              10       4
# 96            20              11       5
# 97            18              11       4
# 98            20               9       5
# 99            18              10       4
#
# [100 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['updated_cgpa', 'semester_marks', 'placed'], dtype='object')

# %%
df['half'] = df['updated_cgpa'].where(df['updated_cgpa'] > 7, other = 0)
df.head(10)
# Out:
#    updated_cgpa  semester_marks  placed  half
# 0            20              10       5    20
# 1            18               9       4    18
# 2            20              12       5    20
# 3            18              11       5    18
# 4            19              11       5    19
# 5            20              10       5    20
# 6            17              11       4    17
# 7            18              10       4    18
# 8            18              10       4    18
# 9            19              11       5    19
