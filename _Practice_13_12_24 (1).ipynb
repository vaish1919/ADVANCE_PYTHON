# %%
import pandas as pd

# %%
df = pd.read_csv("covid_toy - covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head(5)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['gender'] = df['gender'].map({"Female":0, "Male":1})

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['cough'] = df['cough'].map({"Mild":0, "Strong":1})

# %%
df
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60       1  103.0      4    Kolkata        No
# 1    27       1  100.0      4      Delhi       Yes
# 2    42       1  101.0      4      Delhi        No
# 3    31       0   98.0      4    Kolkata        No
# 4    65       0  101.0      4     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12       0  104.0      4  Bangalore        No
# 96   51       0  101.0      5    Kolkata       Yes
# 97   20       0  101.0      4  Bangalore        No
# 98    5       0   98.0      5     Mumbai        No
# 99   10       0   98.0      5    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#               age      gender       fever       cough
# count  100.000000  100.000000   90.000000  100.000000
# mean    44.220000    0.410000  100.844444    0.380000
# std     24.878931    0.494311    2.054926    0.487832
# min      5.000000    0.000000   98.000000    0.000000
# 25%     20.000000    0.000000   99.000000    0.000000
# 50%     45.000000    0.000000  101.000000    0.000000
# 75%     66.500000    1.000000  102.750000    1.000000
# max     84.000000    1.000000  104.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    int64
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    int64
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 4.8+ KB

# %%
top_left_corner_df = df.iloc[:4, :3]
top_left_corner_df
# Out:
#    age  gender  fever
# 0   60       1  103.0
# 1   27       1  100.0
# 2   42       1  101.0
# 3   31       0   98.0

# %%
df.loc[1:3,['age','gender']]
# Out:
#    age  gender
# 1   27       1
# 2   42       1
# 3   31       0

# %%
df.shape
# Out:
# (100, 6)

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')]

# %%
p = df.dtypes
p
# Out:
# age            int64
# gender         int64
# fever        float64
# cough          int64
# city          object
# has_covid     object
# dtype: object

# %%
b = df.empty
b
# Out:
# False

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.dropna()
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60       1  103.0      0    Kolkata        No
# 1    27       1  100.0      0      Delhi       Yes
# 2    42       1  101.0      0      Delhi        No
# 3    31       0   98.0      0    Kolkata        No
# 4    65       0  101.0      0     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12       0  104.0      0  Bangalore        No
# 96   51       0  101.0      1    Kolkata       Yes
# 97   20       0  101.0      0  Bangalore        No
# 98    5       0   98.0      1     Mumbai        No
# 99   10       0   98.0      1    Kolkata       Yes
#
# [90 rows x 6 columns]

# %%
i = df.ndim
i
# Out:
# 2

# %%
d = df.size
d
# Out:
# 600

# %%
a = df.values
a
# Out:
# array([[60, 1, 103.0, 0, 'Kolkata', 'No'],
#        [27, 1, 100.0, 0, 'Delhi', 'Yes'],
#        [42, 1, 101.0, 0, 'Delhi', 'No'],
#        [31, 0, 98.0, 0, 'Kolkata', 'No'],
#        [65, 0, 101.0, 0, 'Mumbai', 'No'],
#        [84, 0, nan, 0, 'Bangalore', 'Yes'],
#        [14, 1, 101.0, 1, 'Bangalore', 'No'],
#        [20, 0, nan, 1, 'Mumbai', 'Yes'],
#        [19, 0, 100.0, 1, 'Bangalore', 'No'],
#        [64, 0, 101.0, 0, 'Delhi', 'No'],
#        [75, 0, nan, 0, 'Delhi', 'No'],
#        [65, 0, 98.0, 0, 'Mumbai', 'Yes'],
#        [25, 0, 99.0, 1, 'Kolkata', 'No'],
#        [64, 1, 102.0, 0, 'Bangalore', 'Yes'],
#        [51, 1, 104.0, 0, 'Bangalore', 'No'],
#        [70, 1, 103.0, 1, 'Kolkata', 'Yes'],
#        [69, 0, 103.0, 0, 'Kolkata', 'Yes'],
#        [40, 0, 98.0, 1, 'Delhi', 'No'],
#        [64, 0, 98.0, 0, 'Bangalore', 'Yes'],
#        [42, 0, nan, 1, 'Bangalore', 'Yes'],
#        [12, 1, 98.0, 1, 'Bangalore', 'No'],
#        [73, 1, 98.0, 0, 'Bangalore', 'Yes'],
# ...

# %%
p = df.sort_values(by = 'age')
p.head(10)
# Out:
#     age  gender  fever  cough       city has_covid
# 98    5       0   98.0      1     Mumbai        No
# 75    5       1  102.0      0    Kolkata       Yes
# 88    5       0  100.0      0    Kolkata        No
# 59    6       0  104.0      0    Kolkata       Yes
# 77    8       0  101.0      0    Kolkata        No
# 63   10       1  100.0      0  Bangalore        No
# 99   10       0   98.0      1    Kolkata       Yes
# 78   11       1  100.0      0  Bangalore       Yes
# 51   11       0  100.0      1    Kolkata       Yes
# 20   12       1   98.0      1  Bangalore        No

# %%
df['AGE'] = df['age'].astype(int)
df
# Out:
#     age  gender  fever  cough       city has_covid  AGE
# 0    60       1  103.0      0    Kolkata        No   60
# 1    27       1  100.0      0      Delhi       Yes   27
# 2    42       1  101.0      0      Delhi        No   42
# 3    31       0   98.0      0    Kolkata        No   31
# 4    65       0  101.0      0     Mumbai        No   65
# ..  ...     ...    ...    ...        ...       ...  ...
# 95   12       0  104.0      0  Bangalore        No   12
# 96   51       0  101.0      1    Kolkata       Yes   51
# 97   20       0  101.0      0  Bangalore        No   20
# 98    5       0   98.0      1     Mumbai        No    5
# 99   10       0   98.0      1    Kolkata       Yes   10
#
# [100 rows x 7 columns]

# %%
df = df.drop(columns = ['AGE'])

# %%
p = df

# %%
df
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60       1  103.0      0    Kolkata        No
# 1    27       1  100.0      0      Delhi       Yes
# 2    42       1  101.0      0      Delhi        No
# 3    31       0   98.0      0    Kolkata        No
# 4    65       0  101.0      0     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12       0  104.0      0  Bangalore        No
# 96   51       0  101.0      1    Kolkata       Yes
# 97   20       0  101.0      0  Bangalore        No
# 98    5       0   98.0      1     Mumbai        No
# 99   10       0   98.0      1    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['cough'] = df['cough'].add(4)
df
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60       1  103.0      4    Kolkata        No
# 1    27       1  100.0      4      Delhi       Yes
# 2    42       1  101.0      4      Delhi        No
# 3    31       0   98.0      4    Kolkata        No
# 4    65       0  101.0      4     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12       0  104.0      4  Bangalore        No
# 96   51       0  101.0      5    Kolkata       Yes
# 97   20       0  101.0      4  Bangalore        No
# 98    5       0   98.0      5     Mumbai        No
# 99   10       0   98.0      5    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
s = df.count()
s
# Out:
# age          100
# gender       100
# fever         90
# cough        100
# city         100
# has_covid    100
# dtype: int64

# %%
p = df.max()
p
# Out:
# age              84
# gender            1
# fever         104.0
# cough             5
# city         Mumbai
# has_covid       Yes
# dtype: object

# %%
q = df.min()
q
# Out:
# age                  5
# gender               0
# fever             98.0
# cough                4
# city         Bangalore
# has_covid           No
# dtype: object

# %%
r = df['age'].mean()
r
# Out:
# 44.22

# %%
s = df['age'].median()
s
# Out:
# 45.0

# %%
g = df.filter(items = ['age','gender'])
g
# Out:
#     age  gender
# 0    60       1
# 1    27       1
# 2    42       1
# 3    31       0
# 4    65       0
# ..  ...     ...
# 95   12       0
# 96   51       0
# 97   20       0
# 98    5       0
# 99   10       0
#
# [100 rows x 2 columns]

# %%
df[['age','gender']]
# Out:
#     age  gender
# 0    60       1
# 1    27       1
# 2    42       1
# 3    31       0
# 4    65       0
# ..  ...     ...
# 95   12       0
# 96   51       0
# 97   20       0
# 98    5       0
# 99   10       0
#
# [100 rows x 2 columns]

# %%
 p =  df.rename(columns = {'age':'updated_age',
                          'has_covid':'Positive'})
p
# Out:
#     updated_age  gender  fever  cough       city Positive
# 0            60       1  103.0      4    Kolkata       No
# 1            27       1  100.0      4      Delhi      Yes
# 2            42       1  101.0      4      Delhi       No
# 3            31       0   98.0      4    Kolkata       No
# 4            65       0  101.0      4     Mumbai       No
# ..          ...     ...    ...    ...        ...      ...
# 95           12       0  104.0      4  Bangalore       No
# 96           51       0  101.0      5    Kolkata      Yes
# 97           20       0  101.0      4  Bangalore       No
# 98            5       0   98.0      5     Mumbai       No
# 99           10       0   98.0      5    Kolkata      Yes
#
# [100 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int32
#  1   gender     100 non-null    int64
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    int64
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int32(1), int64(2), object(2)
# memory usage: 4.4+ KB

# %%
df = df.dropna()

# %%
df['fever'] = df['fever'].astype(int)
# Out:
# C:\Users\vgshi\AppData\Local\Temp\ipykernel_12140\1669513497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fever'] = df['fever'].astype(int)

# %%
df
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60       1    103      4    Kolkata        No
# 1    27       1    100      4      Delhi       Yes
# 2    42       1    101      4      Delhi        No
# 3    31       0     98      4    Kolkata        No
# 4    65       0    101      4     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12       0    104      4  Bangalore        No
# 96   51       0    101      5    Kolkata       Yes
# 97   20       0    101      4  Bangalore        No
# 98    5       0     98      5     Mumbai        No
# 99   10       0     98      5    Kolkata       Yes
#
# [90 rows x 6 columns]
