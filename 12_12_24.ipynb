# %% [markdown]
# # Pandas

# %% [markdown]
# - It is an open source library that is used for handle data manipulation
#
# ## Data Structure of Pandas ==>
#
# - 1] Series ==> It is one-dimensional array It contains only values not column name.
# - 2] DataFrame ==> It is multi-dimensional array. It contains values with column name.

# %%
import pandas as pd

# %% [markdown]
# # Series

# %%
a = pd.Series([1,45,78,90])
a
# Out:
# 0     1
# 1    45
# 2    78
# 3    90
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # DataFrame

# %%
a = {
    "Emp_ID" : [1,2,3,4,5,6,7,8],
    "Name" : ['Sam','Raj','Nidhi','Aniket','Sam','Pallavi','Garvit','Sam'],
    "Department": ['IT','Sales','IT','IT','Sales','IT','Operations','Sales'],
    "Working_hours": [8,9,9,9,8,9,8,8]
    
}

# %%
type(a)
# Out:
# dict

# %%
df = pd.DataFrame(a)
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2      Raj       Sales              9
# 2       3    Nidhi          IT              9
# 3       4   Aniket          IT              9
# 4       5      Sam       Sales              8
# 5       6  Pallavi          IT              9
# 6       7   Garvit  Operations              8
# 7       8      Sam       Sales              8

# %% [markdown]
# # How can we import or export our Dataframe

# %%
# to_csv ==> use to export file of dataframe
# read_csv ==> used to display or read file

df.to_csv("C:\\Users\\vgshi\\OneDrive\\Desktop\\XYZ.csv", index = False)

# %%
pd.read_csv("C:\\Users\\vgshi\\OneDrive\\Desktop\\XYZ.csv")
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2      Raj       Sales              9
# 2       3    Nidhi          IT              9
# 3       4   Aniket          IT              9
# 4       5      Sam       Sales              8
# 5       6  Pallavi          IT              9
# 6       7   Garvit  Operations              8
# 7       8      Sam       Sales              8

# %%
df1 = pd.read_csv("movie_dataset.csv")
df1
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ## How can we check top 5 data ?

# %%
df.head()
# Out:
#    Emp_ID    Name Department  Working_hours
# 0       1     Sam         IT              8
# 1       2     Raj      Sales              9
# 2       3   Nidhi         IT              9
# 3       4  Aniket         IT              9
# 4       5     Sam      Sales              8

# %%
df.head(2)
# Out:
#    Emp_ID Name Department  Working_hours
# 0       1  Sam         IT              8
# 1       2  Raj      Sales              9

# %% [markdown]
# # How can we check bottom data ?

# %%
df.tail()
# Out:
#    Emp_ID     Name  Department  Working_hours
# 3       4   Aniket          IT              9
# 4       5      Sam       Sales              8
# 5       6  Pallavi          IT              9
# 6       7   Garvit  Operations              8
# 7       8      Sam       Sales              8

# %%
df.tail(3)
# Out:
#    Emp_ID     Name  Department  Working_hours
# 5       6  Pallavi          IT              9
# 6       7   Garvit  Operations              8
# 7       8      Sam       Sales              8

# %% [markdown]
# ## How can we check random indexed data ?

# %%
df.sample(3)
# Out:
#    Emp_ID     Name Department  Working_hours
# 7       8      Sam      Sales              8
# 2       3    Nidhi         IT              9
# 5       6  Pallavi         IT              9

# %% [markdown]
# ## How can we check total shape of data ?

# %%
df.shape
# Out:
# (8, 4)

# %% [markdown]
# ## How can we check total columns in a dataframe ?

# %%
df.columns
# Out:
# Index(['Emp_ID', 'Name', 'Department', 'Working_hours'], dtype='object')

# %% [markdown]
# ## Case - 1
# -  You have to update 'Aniket'  to 'Yamini' and 'Raj' to 'Rajat'

# %%
df['Name']
# Out:
# 0        Sam
# 1        Raj
# 2      Nidhi
# 3     Aniket
# 4        Sam
# 5    Pallavi
# 6     Garvit
# 7        Sam
# Name: Name, dtype: object

# %%
df['Name'][1] = 'Rajat'
df['Name'][3] ='Yamini'
# Out:
# C:\Users\vgshi\AppData\Local\Temp\ipykernel_3892\610799389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][1] = 'Rajat'
# C:\Users\vgshi\AppData\Local\Temp\ipykernel_3892\610799389.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][3] ='Yamini'

# %%
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2    Rajat       Sales              9
# 2       3    Nidhi          IT              9
# 3       4   Yamini          IT              9
# 4       5      Sam       Sales              8
# 5       6  Pallavi          IT              9
# 6       7   Garvit  Operations              8
# 7       8      Sam       Sales              8

# %%
df['Working_hours'][1] = 10
# Out:
# C:\Users\vgshi\AppData\Local\Temp\ipykernel_3892\4138729351.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Working_hours'][1] = 10
# ...

# %%
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2    Rajat       Sales             10
# 2       3    Nidhi          IT              9
# 3       4   Yamini          IT              9
# 4       5      Sam       Sales              8
# 5       6  Pallavi          IT              9
# 6       7   Garvit  Operations              8
# 7       8      Sam       Sales              8

# %% [markdown]
# ## How can we check total sub_categoires frquency of a column?

# %%
df['Name'].value_counts()
# Out:
# Name
# Sam        3
# Rajat      1
# Nidhi      1
# Yamini     1
# Pallavi    1
# Garvit     1
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# IT            4
# Sales         3
# Operations    1
# Name: count, dtype: int64

# %% [markdown]
# ## How can we handle missing dat ?
#
# - Using ==>  isnull()

# %%
df.isnull().sum()
# Out:
# Emp_ID           0
# Name             0
# Department       0
# Working_hours    0
# dtype: int64

# %%
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2    Rajat       Sales             10
# 2       3    Nidhi          IT              9
# 3       4   Yamini          IT              9
# 4       5      Sam       Sales              8
# 5       6  Pallavi          IT              9
# 6       7   Garvit  Operations              8
# 7       8      Sam       Sales              8

# %%
df['Name'][2] = None
df['Department'][4] = None
df['Department'][5] = None
# Out:
# C:\Users\vgshi\AppData\Local\Temp\ipykernel_3892\1359829107.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][2] = None
# C:\Users\vgshi\AppData\Local\Temp\ipykernel_3892\1359829107.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...

# %%
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2    Rajat       Sales             10
# 2       3     None          IT              9
# 3       4   Yamini          IT              9
# 4       5      Sam        None              8
# 5       6  Pallavi        None              9
# 6       7   Garvit  Operations              8
# 7       8      Sam       Sales              8

# %%
df.isnull().sum()
# Out:
# Emp_ID           0
# Name             1
# Department       2
# Working_hours    0
# dtype: int64

# %%
df = df.dropna()      # dropna ==> used to  delete all null values

# %%
df.isnull().sum()
# Out:
# Emp_ID           0
# Name             0
# Department       0
# Working_hours    0
# dtype: int64

# %%
df
# Out:
#    Emp_ID    Name  Department  Working_hours
# 0       1     Sam          IT              8
# 1       2   Rajat       Sales             10
# 3       4  Yamini          IT              9
# 6       7  Garvit  Operations              8
# 7       8     Sam       Sales              8

# %%
# CASE 1 ===>  Dataframe

# STudent informTION
# student id
# courssse name
# course duration
# fees

# data import and export 
# use all methods
